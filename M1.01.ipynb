# %% [markdown]
# # 📝 Exercise M1.01

# %% [markdown]
# Imagine we are interested in predicting penguins species based on two of their
# body measurements: culmen length and culmen depth. First we want to do some
# data exploration to get a feel for the data.
#
# What are the features? What is the target?

# %% [markdown]
# The data is located in `../datasets/penguins_classification.csv`, load it with
# `pandas` into a `DataFrame`.

# %%
import pandas as pd

penguins = pd.read_csv('./penguins_classification.csv')
penguins.head()
# Out:
#    Culmen Length (mm)  Culmen Depth (mm) Species
# 0                39.1               18.7  Adelie
# 1                39.5               17.4  Adelie
# 2                40.3               18.0  Adelie
# 3                36.7               19.3  Adelie
# 4                39.3               20.6  Adelie

# %%
features = [
    'Culmen Length (mm)',
    'Culmen Depth (mm)'
]
target = 'Species'
# X = penguins[features]
# y = penguins[target]
# X.head()

# %% [markdown]
# Show a few samples of the data.
#
# How many features are numerical? How many features are categorical?

# %%
penguins.head(20)
# Out:
#     Culmen Length (mm)  Culmen Depth (mm) Species
# 0                 39.1               18.7  Adelie
# 1                 39.5               17.4  Adelie
# 2                 40.3               18.0  Adelie
# 3                 36.7               19.3  Adelie
# 4                 39.3               20.6  Adelie
# 5                 38.9               17.8  Adelie
# 6                 39.2               19.6  Adelie
# 7                 34.1               18.1  Adelie
# 8                 42.0               20.2  Adelie
# 9                 37.8               17.1  Adelie
# 10                37.8               17.3  Adelie
# 11                41.1               17.6  Adelie
# 12                38.6               21.2  Adelie
# 13                34.6               21.1  Adelie
# 14                36.6               17.8  Adelie
# 15                38.7               19.0  Adelie
# 16                42.5               20.7  Adelie
# 17                34.4               18.4  Adelie
# 18                46.0               21.5  Adelie
# 19                37.8               18.3  Adelie

# %%
# Write your code here.
numerical_features = penguins[features].select_dtypes(include=['number'])
num_numerical_features = numerical_features.shape[1]
print(numerical_features)
print(f'Number of numerical features: {num_numerical_features}')
categorical_features = penguins[features].select_dtypes(include=['object', 'category'])
num_categorical_features = categorical_features.shape[1]
print(f'Number of categorical features: {num_categorical_features}')
# print(categorical_features)
# Out:
#      Culmen Length (mm)  Culmen Depth (mm)
# 0                  39.1               18.7
# 1                  39.5               17.4
# 2                  40.3               18.0
# 3                  36.7               19.3
# 4                  39.3               20.6
# ..                  ...                ...
# 337                55.8               19.8
# 338                43.5               18.1
# 339                49.6               18.2
# 340                50.8               19.0
# 341                50.2               18.7
#
# [342 rows x 2 columns]
# Number of numerical features: 2
# Number of categorical features: 0

# %% [markdown]
# What are the different penguins species available in the dataset and how many
# samples of each species are there? Hint: select the right column and use the
# [`value_counts`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.value_counts.html)
# method.

# %%
# Write your code here.
#i want the to see in the target how many species there are and how many samples of each species
species_counts = penguins[target].value_counts()
print(species_counts)
print(f'Number of species: {species_counts.shape[0]}')#zero index will count the number of species
# Out:
# Species
# Adelie       151
# Gentoo       123
# Chinstrap     68
# Name: count, dtype: int64
# Number of species: 3

# %% [markdown]
# Plot histograms for the numerical features

# %%
_ = penguins.hist(figsize=(20, 14))

# %% [markdown]
# Show features distribution for each class. Hint: use
# [`seaborn.pairplot`](https://seaborn.pydata.org/generated/seaborn.pairplot.html)

# %%
# Write your code here.

# %% [markdown]
# Looking at these distributions, how hard do you think it would be to classify
# the penguins only using `"culmen depth"` and `"culmen length"`?
